# %% [markdown]
# # Lab 8: Monte Carlo Markov Chain (MCMC)

# %% [markdown]
# **Exercise**: Modelo de Ising 2D
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/fe/2D_ising_model_on_lattice.svg" width="600">
#
# Como aplicación de la distribución canónica en Física estadística tenemos el modelo de Ising en 2D.
# Para el caso de un material paramagnético para átomos de spin $1/2$ y momento magnetico $\mu_0$ en presencia de un campo magnético externo $H$, se obtiene, una magnetización media que depende del campo y la temperatura
# 1. Realizar la simulación mediante el uso del método de Metrópolis Monte Carlo en el cual se visitan todos los
# posibles spines de la red cristalina del material y se intentan inversiones bajo
# condiciones adecuadas de los mismos.
# 2. Mediante la simulación de este sistema, monstrar, que la distribución canónica de la magnetización clásica es muy acertada.
# 3. Consular el resultado analítico y comparar con la simulación de MC.
